# %%
import sys
import os
module_path = os.path.abspath(os.path.join(os.pardir, os.pardir))
if module_path not in sys.path:    
    sys.path.append(module_path)
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:    
    sys.path.append(module_path)
import pandas as pd
#import seaborn as sns
import platform
from sleep_stage_config import Config
from utilities.utils import *
from sklearn.preprocessing import Normalizer
#sns.set(style='whitegrid', rc={'axes.facecolor': '#EFF2F7'})
import hrvanalysis as hrvana
from datetime import datetime
from pathlib import Path
from tqdm import tqdm

# %% [markdown]
# ## This tutorial will explain the feature extraction pipeline for activity counts and heart rate variabilities in details
# This tutorial only focuses on the pipline of feature extraction for each modality. We didn't align the actigraphy data and RR interval data by sleep epochs. You could find detailed information about aligning activity counts and RR intervals in `align_actigraphy_rri.py`

# %%
acc_path = r"\Dataset\MESA\actigraphy"   # the directory is the actigraphy data you downloaded from MESA
acc_feature_output_path = r"\tmp\sleep\act_features" # the directory is the actigraphy feature you want to save
hr_path = r"\Dataset\MESA\annotations-rpoints" # the directory is the R-points you downloaded from MESA
admin_file_path = r"\Dataset\MESA\mesa-sleep-dataset-0.3.0.csv" # the directory is the admin data you downloaded from MESA
hrv_feature_output_path = r"\tmp\sleep\hrv_features" # the directory is the HRV features you want to save
standarize_feature = True

# %%
admin_df = pd.read_csv(admin_file_path)
total_subjects_list = admin_df['mesaid'].unique()

# %%
all_acc_files = os.listdir(acc_path)
all_hr_files = os.listdir(hr_path)

# %%
len(all_hr_files)
# Out:
# 1966

# %% [markdown]
# ### Part 1 The pipeline of feature extraction for heart rate variability in details
# Note:
# In our paper, we only used a single window length of 30s to extract the features related to RR-interval. This method will diminish physiological meaning of these features but yield a better classification outcome.

# %%
hrv_win = 0 # 0 means we use one sleep epoch as the window length (every 30s)

# %%
all_hr_files[0]
# Out:
# 'mesa-sleep-0001-rpoint.csv'

# %%
# only extract the HRV features if the subject is in the valid subject list
for PID in tqdm(total_subjects_list):
    mesa_id = "%04d" % PID
    hr_inlist_idx = [s for s in all_hr_files if mesa_id in s]
#     print("processing pid: %s" % os.path.basename(file).split("-")[2])
#     mesa_id = os.path.basename(file).split("-")[2]
    if len(hr_inlist_idx) > 0: # the pid is in the file list.
        hr_file_idx = all_hr_files.index(''.join(hr_inlist_idx))
        hr_df = pd.read_csv(os.path.join(hr_path, all_hr_files[hr_file_idx]))

        hr_df = hr_df[hr_df['TPoint'] > 0]
        hr_df['RR Intervals'] = hr_df['seconds'].diff() * 1000
        hr_df['RR Intervals'].fillna(hr_df['RR Intervals'].mean(), inplace=True) # make sure the data export from PSG software doesn't contain Nan
        clean_rri = hr_df['RR Intervals'].values
        clean_rri = hrvana.remove_outliers(rr_intervals=clean_rri, low_rri=300, high_rri=2000)
        clean_rri = hrvana.interpolate_nan_values(rr_intervals=clean_rri, interpolation_method="linear")
        clean_rri = hrvana.remove_ectopic_beats(rr_intervals=clean_rri, method="malik")
        clean_rri = hrvana.interpolate_nan_values(rr_intervals=clean_rri)
        hr_df["RR Intervals"] = clean_rri
        # calculate the Heart Rate
        hr_df['HR'] = np.round((60000.0 / hr_df['RR Intervals']), 0)

        # filter RRI if the RR intervals doesn't contain at least 4 valid beats
        t1 = hr_df.epoch.value_counts().reset_index().rename({'index': 'epoch_idx', 'epoch': 'count'}, axis=1)
        invalid_idx = set(t1[t1['count'] < 3]['epoch_idx'].values)
        del t1
        hr_df = hr_df[~hr_df['epoch'].isin(list(invalid_idx))]
        feature_list = []
        # go through all sleep epochs and extract HRV features from them
        for index, hr_epoch_idx in enumerate(hr_df['epoch'].unique()):
            gt_label = hr_df[hr_df['epoch'] == hr_epoch_idx]["stage"].values[0]  # in MESA r-points files, the stage is annotated by the sleep experts
            if hrv_win != 0:  # if you want get the features from a 5 min window, please set hrv_win = 10, as per sleep epoch is 30s
                offset = int(np.floor(hrv_win/2))
                tmp_hr_df = hr_df[hr_df['epoch'].isin(np.arange(hr_epoch_idx-offset, hr_epoch_idx+offset))]
            else:
                tmp_hr_df = hr_df[hr_df['epoch'] == hr_epoch_idx]
            try:  # check to see if the first time stamp is empty
                start_sec = float(tmp_hr_df['seconds'].head(1) * 1.0)
            except Exception as ee:
                print("Exception %s, source dataset: %s" % (ee, tmp_hr_df['seconds'].head(1)))
            # calculate the HRV features for each epoch
            rr_epoch = tmp_hr_df['RR Intervals'].values
            all_hr_features = {}
            try:
                all_hr_features.update(hrvana.get_time_domain_features(rr_epoch))
            except Exception as ee:
                print("processed time domain features with error message: {}".format(str(ee)))
            try:
                all_hr_features.update(hrvana.get_frequency_domain_features(rr_epoch))
            except Exception as ee:
                print("processed frequency domain features with error message: {}".format(str(ee)))
            try:
                all_hr_features.update(hrvana.get_poincare_plot_features(rr_epoch))
            except Exception as ee:
                print("processed poincare features: {} with error message".format(str(ee)))
            try:
                all_hr_features.update(hrvana.get_csi_cvi_features(rr_epoch))
            except Exception as ee:        
                print("processed csi cvi domain features: {} with error message".format(str(ee)))
            try:
                all_hr_features.update(hrvana.get_geometrical_features(rr_epoch))
            except Exception as ee:
                print("processed geometrical features: {} with error message".format(str(ee)))

            all_hr_features.update({'stages': gt_label
                                    , 'mesaid': str(mesa_id)                            
                                    , 'epoch': hr_epoch_idx
                                    #, 'index': index
                                    })
            feature_list.append(all_hr_features)
        hrv_feature_df = pd.DataFrame(feature_list)
        hrv_feature_df.to_csv(os.path.join(hrv_feature_output_path, (mesa_id + '_hrv_features.csv')), index=False)
# Out:
#   0%|                                                                                         | 0/2237 [00:00<?, ?it/s]
# 218 outlier(s) have been deleted.
# The outlier(s) value(s) are : [250.0, 296.875, 261.71900000008463, 242.18800000016927, 222.65599999991537, 281.25, 8207.030999999915, 5132.813000000169, 2203.125, 25617.18699999983, 22882.81200000074, 51914.06200000074, 12632.81299999926, 4910.156000000825, 4054.6869999998307, 4972.655999999915, 5054.68799999926, 24996.094000000085, 14804.68799999926, 2371.0940000000846, 3902.3430000006556, 80726.56300000017, 5367.186999999831, 5613.280999999915, 4148.436999999831, 9894.530999999915, 8386.718000000656, 28371.094000000085, 7710.938000000169, 3394.531000000825, 3476.5630000001693, 7765.625, 3531.25, 3484.375, 9613.281000000825, 2386.718999999175, 5023.438000000169, 8996.093000000656, 4320.313000000169, 7695.313000000169, 14210.93699999983, 2585.9380000001693, 2574.2190000000846, 4304.688000000169, 24964.844000000085, 4046.875, 5019.530999999915, 5808.592999999746, 29187.5, 14605.469000000085, 3300.7809999999154, 3324.2190000000846, 2542.967999999746, 5851.563000000169, 2542.9690000000846, 3390.625, 2554.6880000001693, 3421.875, 3414.0619999998307, 70964.84400000008, 46246.094000000085, 15777.33999999873, 5949.219999998604, 2691.4099999994505, 52847.6499999997, 33128.8999999997, 5289.059999999154, 12820.32000000072, 27855.469999998604, 16730.469999998604, 8039.069999998901, 7152.3400000005495, 6601.560000000973, 41781.25, 15890.629999999874, 5460.940000000846, 5382.810000000973, 8238.279999999577, 57089.84000000055, 8722.65999999945, 51585.93999999903, 2660.1599999994505, 4406.25, 18488.280000001396, 32433.59000000055, 18175.780000001396, 7613.280000001396, 34929.690000000846, 4476.559999999154, 10394.530000001396, 15328.119999998307, 25882.809999999154, 39117.190000000846, 7996.0900000005495, 3695.3099999991537, 9296.880000001693, 13855.469999998604, 7054.690000000846, 16679.68999999721, 76789.05999999915, 3484.3800000016927, 16414.059999999154, 5492.180000001099, 20968.75, 17789.059999999154, 4878.9100000030885, 11839.84000000055, 7449.219999998604, 8542.969999998604, 4292.970000002242, 44496.1000000003, 3511.720000002242, 12402.34000000055, 7968.75, 10875.0, 22082.030000001396, 9203.129999998055, 285781.25, 9226.559999999154, 8242.180000001099, 6785.1599999994505, 3394.529999997758, 6820.320000002539, 5296.870000001945, 8660.149999999703, 5203.129999998055, 11554.690000000846, 20824.220000002242, 4289.059999999154, 3488.279999997758, 50437.5, 11246.100000000297, 16636.720000002242, 4500.0, 7160.1599999994505, 3597.6600000030885, 14910.160000003088, 8152.3400000005495, 19679.690000000846, 11699.219999998604, 6445.320000002539, 4597.6599999994505, 40332.02999999776, 11324.219999998604, 9757.809999999154, 22105.469999998604, 13332.029999997758, 6250.0, 5683.600000000297, 3722.649999999703, 13527.339999996912, 7980.469999998604, 21714.84000000055, 64890.629999998055, 20136.720000002242, 8542.970000002242, 19445.32000000254, 17304.68999999721, 4160.1599999994505, 3691.4100000030885, 6898.439999997208, 6835.940000000846, 67937.5, 2792.969999998604, 34875.0, 10332.030000001396, 22242.190000004484, 4722.6600000030885, 28414.06000000279, 16804.690000004484, 26445.309999995516, 29320.31000000279, 19769.530000001396, 6027.3400000041875, 21339.83999999691, 3500.0, 11003.909999995813, 9871.089999996912, 63980.45999999522, 15703.119999998307, 4484.380000001693, 29554.68999999721, 3804.6899999972084, 16835.93999999721, 4363.27999999412, 4578.119999998307, 14976.560000002792, 9511.72000000588, 3707.040000004781, 17066.41000000309, 10320.320000006177, 4445.309999995516, 3714.8400000005495, 3804.680000001099, 3750.0, 5320.309999995516, 4726.560000002792, 6484.380000001693, 4425.790000001143, 5265.619999998307, 13746.09000000055, 6156.25, 5421.880000001693, 19437.5, 11925.779999997758, 54500.0, 60453.12999999442, 4675.780000005034, 10621.09000000055, 7000.0, 24929.68999999721, 11691.40999999945, 19679.68999999721, 5695.310000002792, 54292.97000000224, 285.1599999994505, 226.56000000279164, 296.8699999983073]
# 289 ectopic beat(s) have been deleted with malik rule.
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 216, using nperseg = 216
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 222, using nperseg = 222
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 215, using nperseg = 215
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 157, using nperseg = 157
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 169, using nperseg = 169
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 35, using nperseg = 35
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 70, using nperseg = 70
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 22, using nperseg = 22
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 27, using nperseg = 27
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 99, using nperseg = 99
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 174, using nperseg = 174
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 62, using nperseg = 62
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 88, using nperseg = 88
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 50, using nperseg = 50
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 117, using nperseg = 117
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 171, using nperseg = 171
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 190, using nperseg = 190
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 77, using nperseg = 77
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 138, using nperseg = 138
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 159, using nperseg = 159
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 184, using nperseg = 184
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 142, using nperseg = 142
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 152, using nperseg = 152
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 156, using nperseg = 156
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 133, using nperseg = 133
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 178, using nperseg = 178
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 58, using nperseg = 58
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 170, using nperseg = 170
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 83, using nperseg = 83
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 55, using nperseg = 55
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 113, using nperseg = 113
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 104, using nperseg = 104
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 97, using nperseg = 97
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 168, using nperseg = 168
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 39, using nperseg = 39
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 52, using nperseg = 52
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 106, using nperseg = 106
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 121, using nperseg = 121
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 137, using nperseg = 137
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 85, using nperseg = 85
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 167, using nperseg = 167
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 154, using nperseg = 154
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 166, using nperseg = 166
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 51, using nperseg = 51
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 19, using nperseg = 19
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 118, using nperseg = 118
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 146, using nperseg = 146
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 107, using nperseg = 107
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 163, using nperseg = 163
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 23, using nperseg = 23
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 84, using nperseg = 84
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 79, using nperseg = 79
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 46, using nperseg = 46
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 61, using nperseg = 61
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 53, using nperseg = 53
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 94, using nperseg = 94
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 90, using nperseg = 90
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 100, using nperseg = 100
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 65, using nperseg = 65
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 114, using nperseg = 114
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 131, using nperseg = 131
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 26, using nperseg = 26
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 112, using nperseg = 112
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 20, using nperseg = 20
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 12, using nperseg = 12
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 111, using nperseg = 111
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 89, using nperseg = 89
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 140, using nperseg = 140
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 93, using nperseg = 93
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 151, using nperseg = 151
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 123, using nperseg = 123
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 10, using nperseg = 10
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 92, using nperseg = 92
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 155, using nperseg = 155
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 103, using nperseg = 103
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 101, using nperseg = 101
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 71, using nperseg = 71
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 134, using nperseg = 134
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 74, using nperseg = 74
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 11, using nperseg = 11
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 148, using nperseg = 148
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 47, using nperseg = 47
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 109, using nperseg = 109
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 67, using nperseg = 67
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 44, using nperseg = 44
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 141, using nperseg = 141
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 31, using nperseg = 31
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 162, using nperseg = 162
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 150, using nperseg = 150
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 143, using nperseg = 143
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 126, using nperseg = 126
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 91, using nperseg = 91
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 149, using nperseg = 149
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 136, using nperseg = 136
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 33, using nperseg = 33
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 129, using nperseg = 129
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 135, using nperseg = 135
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 30, using nperseg = 30
#   .format(nperseg, input_length))
#   0%|                                                                               | 1/2237 [00:02<1:37:39,  2.62s/it]
# 50 outlier(s) have been deleted.
# The outlier(s) value(s) are : [5265.625, 19558.59375, 38839.84375, 2738.28125, 16390.625, 12562.5, 2781.25, 9160.15625, 8195.3125, 16617.1875, 3625.0, 2218.75, 11144.53125, 2804.6875, 29746.09375, 13773.4375, 18554.6875, 2996.09375, 11019.53125, 2996.09375, 35367.1875, 6328.125, 5078.125, 29488.28125, 9812.5, 3707.03125, 6542.96875, 8152.34375, 2652.34375, 8519.53125, 38812.5, 27984.375, 12734.375, 2835.9375, 6531.25, 3910.15625, 3703.125, 15023.4375, 27093.75, 2695.3125, 269.53125, 2277.34375, 6320.3125, 238.28125, 13289.0625, 17351.5625, 242.1875, 2238.28125, 164.0625, 5867.1875]
# 101 ectopic beat(s) have been deleted with malik rule.
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 225, using nperseg = 225
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 63, using nperseg = 63
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 116, using nperseg = 116
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 119, using nperseg = 119
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 69, using nperseg = 69
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 108, using nperseg = 108
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 13, using nperseg = 13
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 102, using nperseg = 102
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 105, using nperseg = 105
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 48, using nperseg = 48
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 214, using nperseg = 214
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 153, using nperseg = 153
#   .format(nperseg, input_length))
#   0%|                                                                               | 2/2237 [00:04<1:32:24,  2.48s/it]
# 37 outlier(s) have been deleted.
# The outlier(s) value(s) are : [4789.0625, 2199.21875, 2121.09375, 2246.09375, 2203.125, 2242.1875, 4957.03125, 2015.625, 2113.28125, 2078.125, 2566.40625, 2757.8125, 5085.9375, 9734.375, 7281.25, 11281.25, 2160.15625, 14914.0625, 7132.8125, 4535.15625, 2148.4375, 3414.0625, 6523.4375, 6425.78125, 6921.875, 2140.625, 2996.09375, 10054.6875, 2476.5625, 5738.28125, 7371.09375, 4332.03125, 2121.09375, 2652.34375, 3925.78125, 3042.96875, 3292.96875]
# 140 ectopic beat(s) have been deleted with malik rule.
#   0%|                                                                               | 3/2237 [00:06<1:29:01,  2.39s/it]
# 37 outlier(s) have been deleted.
# The outlier(s) value(s) are : [4789.0625, 2199.21875, 2121.09375, 2246.09375, 2203.125, 2242.1875, 4957.03125, 2015.625, 2113.28125, 2078.125, 2566.40625, 2757.8125, 5085.9375, 9734.375, 7281.25, 11281.25, 2160.15625, 14914.0625, 7132.8125, 4535.15625, 2148.4375, 3414.0625, 6523.4375, 6425.78125, 6921.875, 2140.625, 2996.09375, 10054.6875, 2476.5625, 5738.28125, 7371.09375, 4332.03125, 2121.09375, 2652.34375, 3925.78125, 3042.96875, 3292.96875]
# 140 ectopic beat(s) have been deleted with malik rule.
#   0%|▏                                                                              | 4/2237 [00:09<1:26:42,  2.33s/it]
# 106 outlier(s) have been deleted.
# The outlier(s) value(s) are : [2183.59375, 222.65625, 2363.28125, 4300.78125, 2585.9375, 8941.40625, 2378.90625, 261.71875, 5343.75, 2128.90625, 13492.1875, 21816.40625, 11222.65625, 20437.5, 11453.125, 26308.59375, 5902.34375, 51941.40625, 16371.09375, 149187.5, 22246.09375, 44660.15625, 10996.09375, 5031.25, 12664.0625, 29093.75, 7886.71875, 85648.4375, 3136.71875, 56609.375, 6222.65625, 24910.15625, 6242.1875, 12496.09375, 3136.71875, 25894.53125, 10683.59375, 5843.75, 15437.5, 7082.03125, 63738.28125, 12078.125, 41585.9375, 15378.90625, 4113.28125, 62062.5, 8429.6875, 10832.03125, 30046.875, 6070.3125, 5875.0, 16714.84375, 57527.34375, 53933.59375, 4210.9375, 13472.65625, 16781.25, 11355.46875, 113640.625, 45152.34375, 12882.8125, 12160.15625, 12500.0, 5125.0, 2839.84375, 35765.625, 592632.8125, 10718.75, 10585.9375, 5421.875, 104847.65625, 125875.0, 41292.96875, 9250.0, 169292.96875, 4175.78125, 10585.9375, 120164.0625, 10019.53125, 16886.71875, 7734.375, 26332.03125, 8730.46875, 5140.625, 7210.9375, 14933.59375, 9488.28125, 10824.21875, 7464.84375, 7921.875, 4648.4375, 9273.4375, 11636.71875, 14199.21875, 16066.40625, 8199.21875, 7453.125, 10382.8125, 20687.5, 16121.09375, 11343.75, 10636.71875, 16667.96875, 2214.84375, 2191.40625, 292.96875]
# 511 ectopic beat(s) have been deleted with malik rule.
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 64, using nperseg = 64
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 80, using nperseg = 80
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 28, using nperseg = 28
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 25, using nperseg = 25
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 115, using nperseg = 115
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 29, using nperseg = 29
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 120, using nperseg = 120
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 82, using nperseg = 82
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 125, using nperseg = 125
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 127, using nperseg = 127
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 15, using nperseg = 15
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 78, using nperseg = 78
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 75, using nperseg = 75
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 130, using nperseg = 130
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 218, using nperseg = 218
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 68, using nperseg = 68
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 87, using nperseg = 87
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 224, using nperseg = 224
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 144, using nperseg = 144
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 234, using nperseg = 234
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 221, using nperseg = 221
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 228, using nperseg = 228
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 124, using nperseg = 124
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 219, using nperseg = 219
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 217, using nperseg = 217
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 96, using nperseg = 96
#   .format(nperseg, input_length))
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\scipy\signal\spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 238, using nperseg = 238
#   .format(nperseg, input_length))
#   0%|▏                                                                              | 5/2237 [00:11<1:29:34,  2.41s/it]
# processed frequency domain features with error message: arange: cannot compute length
#   0%|▏                                                                              | 5/2237 [00:12<1:30:19,  2.43s/it]
# 41 outlier(s) have been deleted.
# The outlier(s) value(s) are : [289.0625, 2101.5625, 2203.125, 2179.6875, 207.03125, 2058.59375, 3015.625, 2992.1875, 3992.1875, 6339.84375, 3445.3125, 2613.28125, 4707.03125, 2261.71875, 2394.53125, 3035.15625, 2378.90625, 5878.90625, 2238.28125, 3222.65625, 230.46875, 3484.375, 2132.8125, 3964.84375, 156433.59375, 2511.71875, 7121.09375, 2320.3125, 2660.15625, 5976.5625, 3441.40625, 4902.34375, 11070.3125, 7269.53125, 6460.9375, 5972.65625, 12511.71875, 5824.21875, 5808.59375, 7914.0625, 2046.875]
# 186 ectopic beat(s) have been deleted with malik rule.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-143-4a8f471a6d46> in <module>
#      29     feature_list = []
#      30     for index, hr_epoch_idx in enumerate(hr_df['epoch'].unique()):
# ---> 31         gt_label = hr_df[hr_df['epoch'] == hr_epoch_idx]["stage"].values[0]  # in MESA r-points files, the stage is annotated by the sleep experts
#      32         if hrv_win != 0:  # if you want get the features from a 5 min window, please set hrv_win = 10, as per sleep epoch is 30s
#      33             offset = int(np.floor(hrv_win/2))
#
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2789         # Do we have a (boolean) 1d indexer?
#    2790         if com.is_bool_indexer(key):
# -> 2791             return self._getitem_bool_array(key)
#    2792
#    2793         # We are left with two options: a single key, and a collection of keys,
#
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\pandas\core\frame.py in _getitem_bool_array(self, key)
#    2843         key = check_bool_indexer(self.index, key)
#    2844         indexer = key.nonzero()[0]
# -> 2845         return self._take_with_is_copy(indexer, axis=0)
#    2846
#    2847     def _getitem_multilevel(self, key):
#
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\pandas\core\generic.py in _take_with_is_copy(self, indices, axis, **kwargs)
#    3407         See the docstring of `take` for full explanation of the parameters.
#    3408         """
# -> 3409         result = self.take(indices=indices, axis=axis, **kwargs)
#    3410         # Maybe set copy if we didn't actually change the index.
#    3411         if not result._get_axis(axis).equals(self._get_axis(axis)):
#
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\pandas\core\generic.py in take(self, indices, axis, is_copy, **kwargs)
#    3393
#    3394         new_data = self._data.take(
# -> 3395             indices, axis=self._get_block_manager_axis(axis), verify=True
#    3396         )
#    3397         return self._constructor(new_data).__finalize__(self)
#
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\pandas\core\internals\managers.py in take(self, indexer, axis, verify, convert)
#    1392         new_labels = self.axes[axis].take(indexer)
#    1393         return self.reindex_indexer(
# -> 1394             new_axis=new_labels, indexer=indexer, axis=axis, allow_dups=True
#    1395         )
#    1396
#
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\pandas\core\internals\managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy)
#    1270         new_axes = list(self.axes)
#    1271         new_axes[axis] = new_axis
# -> 1272         return type(self)(new_blocks, new_axes)
#    1273
#    1274     def _slice_take_blocks_ax0(self, slice_or_indexer, fill_tuple=None):
#
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\pandas\core\internals\managers.py in __init__(self, blocks, axes, do_integrity_check)
#     141         self._consolidate_check()
#     142
# --> 143         self._rebuild_blknos_and_blklocs()
#     144
#     145     def make_empty(self, axes=None):
#
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\pandas\core\internals\managers.py in _rebuild_blknos_and_blklocs(self)
#     222             rl = blk.mgr_locs
#     223             new_blknos[rl.indexer] = blkno
# --> 224             new_blklocs[rl.indexer] = np.arange(len(rl))
#     225
#     226         if (new_blknos == -1).any():
#
# KeyboardInterrupt:

# %% [markdown]
# ### Part-2 The pipeline of feature extraction for activity counts in details
# Note:
#
# For the actigraphy based sliding window method, the `get_statistic_feature` function will calculate statistic features based on two window-centring methods. The centred window and backwards-looking window. The dataframe passed in as the function's argument will be expanded to include the calculated features. In this tutorial, we show an example of using 20 sleep epochs as the length of the window. In MESA actigraphy, the 370 calculated features will be appended after column *daybynoon* the calculated actigraphy features can be found in `acc_feature_output_path`

# %%
for PID in tqdm(total_subjects_list):
    mesa_id = "%04d" % PID
    # filter Acc and HR based on the overlap records
    print('*' * 100)
    print("Processing subject %s dataset" % mesa_id)
    acc_inlist_idx = [s for s in all_acc_files if mesa_id in s]
    feature_list = []
    if len(acc_inlist_idx) > 0: # the pid is in the file list.
        # get the raw dataset file index
        acc_file_idx = all_acc_files.index(''.join(acc_inlist_idx))
        # load Acc and HR into Pandas
        acc_df = pd.read_csv(os.path.join(acc_path, all_acc_files[acc_file_idx]))
        # filter ACC, as per MESA website recommanded.
        acc_df = acc_df[acc_df['interval'] != 'EXCLUDED']
        #combined_pd = combined_pd.reset_index(drop=True)
        acc_df['timestamp'] = pd.to_datetime(acc_df['linetime'])
        acc_df['base_time'] = pd.to_datetime('00:00:00')
        acc_df['seconds'] = (acc_df['timestamp'] - acc_df['base_time'])
        acc_df['seconds'] = acc_df['seconds'].dt.seconds
        acc_df.drop(['timestamp', 'base_time'], axis=1, inplace=True)
        featnames = get_statistic_feature(acc_df, column_name="activity", windows_size=20)

        list_size_chk = np.array(acc_df[['marker', 'activity']].values.tolist())
        # check whether the activity is empty
        if len(list_size_chk.shape) < 2:
            print(
                "File {f_name} doesn't meet dimension requirement, it's size is {wrong_dim}".format(
                    f_name=all_acc_files[acc_file_idx], wrong_dim=list_size_chk.shape)
            )
        else:
            acc_df = acc_df.fillna(acc_df.median()) # fill the missing data with their median value which is resistant to outliters 
            # standardise and normalise the df
            feature_list = acc_df.columns.to_list() 
            std_feature = [x for x in feature_list if x not in ['two_stages', 'seconds', 'activity', 'interval', 'wake', 'linetime', 'mesaid', 'stages', 'line']]
            if standarize_feature:
                standardize_df_given_feature(acc_df, std_feature, df_name='acc_df', simple_method=False)
            acc_df.to_csv(os.path.join(acc_feature_output_path, (mesa_id + '_act_features.csv')), index=False)
# Out:
#   0%|                                                                                         | 0/2237 [00:00<?, ?it/s]
# ****************************************************************************************************
# Processing subject 0001 dataset
# pre-processing dataset frame using comprehensive method
# quality check on acc_df for column name: offwrist
# quality check on acc_df for column name: marker
# quality check on acc_df for column name: whitelight
# quality check on acc_df for column name: redlight
# quality check on acc_df for column name: greenlight
# quality check on acc_df for column name: bluelight
# quality check on acc_df for column name: dayofweek
# quality check on acc_df for column name: daybymidnight
# quality check on acc_df for column name: daybynoon
# quality check on acc_df for column name: _mean_1
# quality check on acc_df for column name: _mean_centered_1
# quality check on acc_df for column name: _median_1
# quality check on acc_df for column name: _median_centered_1
# quality check on acc_df for column name: _std_1
# quality check on acc_df for column name: _std_centered_1
# quality check on acc_df for column name: _max_1
# quality check on acc_df for column name: _max_centered_1
# quality check on acc_df for column name: _min_1
# quality check on acc_df for column name: _min_centered_1
# quality check on acc_df for column name: _var_1
# quality check on acc_df for column name: _var_centered_1
# quality check on acc_df for column name: _nat_1
# quality check on acc_df for column name: _nat_centered_1
# quality check on acc_df for column name: _anyact_1
# quality check on acc_df for column name: _anyact_centered_1
# quality check on acc_df for column name: _mean_2
# quality check on acc_df for column name: _mean_centered_2
# quality check on acc_df for column name: _median_2
# quality check on acc_df for column name: _median_centered_2
# quality check on acc_df for column name: _std_2
# quality check on acc_df for column name: _std_centered_2
# quality check on acc_df for column name: _max_2
# quality check on acc_df for column name: _max_centered_2
# quality check on acc_df for column name: _min_2
# quality check on acc_df for column name: _min_centered_2
# quality check on acc_df for column name: _var_2
# quality check on acc_df for column name: _var_centered_2
# quality check on acc_df for column name: _nat_2
# quality check on acc_df for column name: _nat_centered_2
# quality check on acc_df for column name: _anyact_2
# quality check on acc_df for column name: _anyact_centered_2
# quality check on acc_df for column name: _mean_3
# quality check on acc_df for column name: _mean_centered_3
# quality check on acc_df for column name: _median_3
# quality check on acc_df for column name: _median_centered_3
# quality check on acc_df for column name: _std_3
# quality check on acc_df for column name: _std_centered_3
# quality check on acc_df for column name: _max_3
# quality check on acc_df for column name: _max_centered_3
# quality check on acc_df for column name: _min_3
# quality check on acc_df for column name: _min_centered_3
# quality check on acc_df for column name: _var_3
# quality check on acc_df for column name: _var_centered_3
# quality check on acc_df for column name: _nat_3
# quality check on acc_df for column name: _nat_centered_3
# quality check on acc_df for column name: _anyact_3
# quality check on acc_df for column name: _anyact_centered_3
# quality check on acc_df for column name: _mean_4
# quality check on acc_df for column name: _mean_centered_4
# quality check on acc_df for column name: _median_4
# quality check on acc_df for column name: _median_centered_4
# quality check on acc_df for column name: _std_4
# quality check on acc_df for column name: _std_centered_4
# quality check on acc_df for column name: _max_4
# quality check on acc_df for column name: _max_centered_4
# quality check on acc_df for column name: _min_4
# quality check on acc_df for column name: _min_centered_4
# quality check on acc_df for column name: _var_4
# quality check on acc_df for column name: _var_centered_4
# quality check on acc_df for column name: _nat_4
# quality check on acc_df for column name: _nat_centered_4
# quality check on acc_df for column name: _anyact_4
# quality check on acc_df for column name: _anyact_centered_4
# quality check on acc_df for column name: _skew_4
# quality check on acc_df for column name: _skew_centered_4
# quality check on acc_df for column name: _kurt_4
# quality check on acc_df for column name: _kurt_centered_4
# quality check on acc_df for column name: _mean_5
# quality check on acc_df for column name: _mean_centered_5
# quality check on acc_df for column name: _median_5
# quality check on acc_df for column name: _median_centered_5
# quality check on acc_df for column name: _std_5
# quality check on acc_df for column name: _std_centered_5
# quality check on acc_df for column name: _max_5
# quality check on acc_df for column name: _max_centered_5
# quality check on acc_df for column name: _min_5
# quality check on acc_df for column name: _min_centered_5
# quality check on acc_df for column name: _var_5
# quality check on acc_df for column name: _var_centered_5
# quality check on acc_df for column name: _nat_5
# quality check on acc_df for column name: _nat_centered_5
# quality check on acc_df for column name: _anyact_5
# quality check on acc_df for column name: _anyact_centered_5
# quality check on acc_df for column name: _skew_5
# quality check on acc_df for column name: _skew_centered_5
# quality check on acc_df for column name: _kurt_5
# quality check on acc_df for column name: _kurt_centered_5
# quality check on acc_df for column name: _mean_6
# quality check on acc_df for column name: _mean_centered_6
# quality check on acc_df for column name: _median_6
# quality check on acc_df for column name: _median_centered_6
# quality check on acc_df for column name: _std_6
# quality check on acc_df for column name: _std_centered_6
# quality check on acc_df for column name: _max_6
# quality check on acc_df for column name: _max_centered_6
# quality check on acc_df for column name: _min_6
# quality check on acc_df for column name: _min_centered_6
# quality check on acc_df for column name: _var_6
# quality check on acc_df for column name: _var_centered_6
# quality check on acc_df for column name: _nat_6
# quality check on acc_df for column name: _nat_centered_6
# quality check on acc_df for column name: _anyact_6
# quality check on acc_df for column name: _anyact_centered_6
# quality check on acc_df for column name: _skew_6
# quality check on acc_df for column name: _skew_centered_6
# quality check on acc_df for column name: _kurt_6
# quality check on acc_df for column name: _kurt_centered_6
# quality check on acc_df for column name: _mean_7
# quality check on acc_df for column name: _mean_centered_7
# quality check on acc_df for column name: _median_7
# quality check on acc_df for column name: _median_centered_7
# quality check on acc_df for column name: _std_7
# quality check on acc_df for column name: _std_centered_7
# quality check on acc_df for column name: _max_7
# quality check on acc_df for column name: _max_centered_7
# quality check on acc_df for column name: _min_7
# quality check on acc_df for column name: _min_centered_7
# quality check on acc_df for column name: _var_7
# quality check on acc_df for column name: _var_centered_7
# quality check on acc_df for column name: _nat_7
# quality check on acc_df for column name: _nat_centered_7
# quality check on acc_df for column name: _anyact_7
# quality check on acc_df for column name: _anyact_centered_7
# quality check on acc_df for column name: _skew_7
# quality check on acc_df for column name: _skew_centered_7
# quality check on acc_df for column name: _kurt_7
# quality check on acc_df for column name: _kurt_centered_7
# quality check on acc_df for column name: _mean_8
# quality check on acc_df for column name: _mean_centered_8
# quality check on acc_df for column name: _median_8
# quality check on acc_df for column name: _median_centered_8
# quality check on acc_df for column name: _std_8
# quality check on acc_df for column name: _std_centered_8
# quality check on acc_df for column name: _max_8
# quality check on acc_df for column name: _max_centered_8
# quality check on acc_df for column name: _min_8
# quality check on acc_df for column name: _min_centered_8
# quality check on acc_df for column name: _var_8
# quality check on acc_df for column name: _var_centered_8
# quality check on acc_df for column name: _nat_8
# quality check on acc_df for column name: _nat_centered_8
# quality check on acc_df for column name: _anyact_8
# quality check on acc_df for column name: _anyact_centered_8
# quality check on acc_df for column name: _skew_8
# quality check on acc_df for column name: _skew_centered_8
# quality check on acc_df for column name: _kurt_8
# quality check on acc_df for column name: _kurt_centered_8
# quality check on acc_df for column name: _mean_9
# quality check on acc_df for column name: _mean_centered_9
# quality check on acc_df for column name: _median_9
# quality check on acc_df for column name: _median_centered_9
# quality check on acc_df for column name: _std_9
# quality check on acc_df for column name: _std_centered_9
# quality check on acc_df for column name: _max_9
# quality check on acc_df for column name: _max_centered_9
# quality check on acc_df for column name: _min_9
# quality check on acc_df for column name: _min_centered_9
# quality check on acc_df for column name: _var_9
# quality check on acc_df for column name: _var_centered_9
# quality check on acc_df for column name: _nat_9
# quality check on acc_df for column name: _nat_centered_9
# quality check on acc_df for column name: _anyact_9
# quality check on acc_df for column name: _anyact_centered_9
# quality check on acc_df for column name: _skew_9
# quality check on acc_df for column name: _skew_centered_9
# quality check on acc_df for column name: _kurt_9
# quality check on acc_df for column name: _kurt_centered_9
# quality check on acc_df for column name: _mean_10
# quality check on acc_df for column name: _mean_centered_10
# quality check on acc_df for column name: _median_10
# quality check on acc_df for column name: _median_centered_10
# quality check on acc_df for column name: _std_10
# quality check on acc_df for column name: _std_centered_10
# quality check on acc_df for column name: _max_10
# quality check on acc_df for column name: _max_centered_10
# quality check on acc_df for column name: _min_10
# quality check on acc_df for column name: _min_centered_10
# quality check on acc_df for column name: _var_10
# quality check on acc_df for column name: _var_centered_10
# quality check on acc_df for column name: _nat_10
# quality check on acc_df for column name: _nat_centered_10
# quality check on acc_df for column name: _anyact_10
# quality check on acc_df for column name: _anyact_centered_10
# quality check on acc_df for column name: _skew_10
# quality check on acc_df for column name: _skew_centered_10
# quality check on acc_df for column name: _kurt_10
# quality check on acc_df for column name: _kurt_centered_10
# quality check on acc_df for column name: _mean_11
# quality check on acc_df for column name: _mean_centered_11
# quality check on acc_df for column name: _median_11
# quality check on acc_df for column name: _median_centered_11
# quality check on acc_df for column name: _std_11
# quality check on acc_df for column name: _std_centered_11
# quality check on acc_df for column name: _max_11
# quality check on acc_df for column name: _max_centered_11
# quality check on acc_df for column name: _min_11
# quality check on acc_df for column name: _min_centered_11
# quality check on acc_df for column name: _var_11
# quality check on acc_df for column name: _var_centered_11
# quality check on acc_df for column name: _nat_11
# quality check on acc_df for column name: _nat_centered_11
# quality check on acc_df for column name: _anyact_11
# quality check on acc_df for column name: _anyact_centered_11
# quality check on acc_df for column name: _skew_11
# quality check on acc_df for column name: _skew_centered_11
# quality check on acc_df for column name: _kurt_11
# quality check on acc_df for column name: _kurt_centered_11
# quality check on acc_df for column name: _mean_12
# quality check on acc_df for column name: _mean_centered_12
# quality check on acc_df for column name: _median_12
# quality check on acc_df for column name: _median_centered_12
# quality check on acc_df for column name: _std_12
# quality check on acc_df for column name: _std_centered_12
# quality check on acc_df for column name: _max_12
# quality check on acc_df for column name: _max_centered_12
# quality check on acc_df for column name: _min_12
# quality check on acc_df for column name: _min_centered_12
# quality check on acc_df for column name: _var_12
# quality check on acc_df for column name: _var_centered_12
# quality check on acc_df for column name: _nat_12
# quality check on acc_df for column name: _nat_centered_12
# quality check on acc_df for column name: _anyact_12
# quality check on acc_df for column name: _anyact_centered_12
# quality check on acc_df for column name: _skew_12
# quality check on acc_df for column name: _skew_centered_12
# quality check on acc_df for column name: _kurt_12
# quality check on acc_df for column name: _kurt_centered_12
# quality check on acc_df for column name: _mean_13
# quality check on acc_df for column name: _mean_centered_13
# quality check on acc_df for column name: _median_13
# quality check on acc_df for column name: _median_centered_13
# quality check on acc_df for column name: _std_13
# quality check on acc_df for column name: _std_centered_13
# quality check on acc_df for column name: _max_13
# quality check on acc_df for column name: _max_centered_13
# quality check on acc_df for column name: _min_13
# quality check on acc_df for column name: _min_centered_13
# quality check on acc_df for column name: _var_13
# quality check on acc_df for column name: _var_centered_13
# quality check on acc_df for column name: _nat_13
# quality check on acc_df for column name: _nat_centered_13
# quality check on acc_df for column name: _anyact_13
# quality check on acc_df for column name: _anyact_centered_13
# quality check on acc_df for column name: _skew_13
# quality check on acc_df for column name: _skew_centered_13
# quality check on acc_df for column name: _kurt_13
# quality check on acc_df for column name: _kurt_centered_13
# quality check on acc_df for column name: _mean_14
# quality check on acc_df for column name: _mean_centered_14
# quality check on acc_df for column name: _median_14
# quality check on acc_df for column name: _median_centered_14
# quality check on acc_df for column name: _std_14
# quality check on acc_df for column name: _std_centered_14
# quality check on acc_df for column name: _max_14
# quality check on acc_df for column name: _max_centered_14
# quality check on acc_df for column name: _min_14
# quality check on acc_df for column name: _min_centered_14
# quality check on acc_df for column name: _var_14
# quality check on acc_df for column name: _var_centered_14
# quality check on acc_df for column name: _nat_14
# quality check on acc_df for column name: _nat_centered_14
# quality check on acc_df for column name: _anyact_14
# quality check on acc_df for column name: _anyact_centered_14
# quality check on acc_df for column name: _skew_14
# quality check on acc_df for column name: _skew_centered_14
# quality check on acc_df for column name: _kurt_14
# quality check on acc_df for column name: _kurt_centered_14
# quality check on acc_df for column name: _mean_15
# quality check on acc_df for column name: _mean_centered_15
# quality check on acc_df for column name: _median_15
# quality check on acc_df for column name: _median_centered_15
# quality check on acc_df for column name: _std_15
# quality check on acc_df for column name: _std_centered_15
# quality check on acc_df for column name: _max_15
# quality check on acc_df for column name: _max_centered_15
# quality check on acc_df for column name: _min_15
# quality check on acc_df for column name: _min_centered_15
# quality check on acc_df for column name: _var_15
# quality check on acc_df for column name: _var_centered_15
# quality check on acc_df for column name: _nat_15
# quality check on acc_df for column name: _nat_centered_15
# quality check on acc_df for column name: _anyact_15
# quality check on acc_df for column name: _anyact_centered_15
# quality check on acc_df for column name: _skew_15
# quality check on acc_df for column name: _skew_centered_15
# quality check on acc_df for column name: _kurt_15
# quality check on acc_df for column name: _kurt_centered_15
# quality check on acc_df for column name: _mean_16
# quality check on acc_df for column name: _mean_centered_16
# quality check on acc_df for column name: _median_16
# quality check on acc_df for column name: _median_centered_16
# quality check on acc_df for column name: _std_16
# quality check on acc_df for column name: _std_centered_16
# quality check on acc_df for column name: _max_16
# quality check on acc_df for column name: _max_centered_16
# quality check on acc_df for column name: _min_16
# quality check on acc_df for column name: _min_centered_16
# quality check on acc_df for column name: _var_16
# quality check on acc_df for column name: _var_centered_16
# quality check on acc_df for column name: _nat_16
# quality check on acc_df for column name: _nat_centered_16
# quality check on acc_df for column name: _anyact_16
# quality check on acc_df for column name: _anyact_centered_16
# quality check on acc_df for column name: _skew_16
# quality check on acc_df for column name: _skew_centered_16
# quality check on acc_df for column name: _kurt_16
# quality check on acc_df for column name: _kurt_centered_16
# quality check on acc_df for column name: _mean_17
# quality check on acc_df for column name: _mean_centered_17
# quality check on acc_df for column name: _median_17
# quality check on acc_df for column name: _median_centered_17
# quality check on acc_df for column name: _std_17
# quality check on acc_df for column name: _std_centered_17
# quality check on acc_df for column name: _max_17
# quality check on acc_df for column name: _max_centered_17
# quality check on acc_df for column name: _min_17
# quality check on acc_df for column name: _min_centered_17
# quality check on acc_df for column name: _var_17
# quality check on acc_df for column name: _var_centered_17
# quality check on acc_df for column name: _nat_17
# quality check on acc_df for column name: _nat_centered_17
# quality check on acc_df for column name: _anyact_17
# quality check on acc_df for column name: _anyact_centered_17
# quality check on acc_df for column name: _skew_17
# quality check on acc_df for column name: _skew_centered_17
# quality check on acc_df for column name: _kurt_17
# quality check on acc_df for column name: _kurt_centered_17
# quality check on acc_df for column name: _mean_18
# quality check on acc_df for column name: _mean_centered_18
# quality check on acc_df for column name: _median_18
# quality check on acc_df for column name: _median_centered_18
# quality check on acc_df for column name: _std_18
# quality check on acc_df for column name: _std_centered_18
# quality check on acc_df for column name: _max_18
# quality check on acc_df for column name: _max_centered_18
# quality check on acc_df for column name: _min_18
# quality check on acc_df for column name: _min_centered_18
# quality check on acc_df for column name: _var_18
# quality check on acc_df for column name: _var_centered_18
# quality check on acc_df for column name: _nat_18
# quality check on acc_df for column name: _nat_centered_18
# quality check on acc_df for column name: _anyact_18
# quality check on acc_df for column name: _anyact_centered_18
# quality check on acc_df for column name: _skew_18
# quality check on acc_df for column name: _skew_centered_18
# quality check on acc_df for column name: _kurt_18
# quality check on acc_df for column name: _kurt_centered_18
# quality check on acc_df for column name: _mean_19
# quality check on acc_df for column name: _mean_centered_19
# quality check on acc_df for column name: _median_19
# quality check on acc_df for column name: _median_centered_19
# quality check on acc_df for column name: _std_19
# quality check on acc_df for column name: _std_centered_19
# quality check on acc_df for column name: _max_19
# quality check on acc_df for column name: _max_centered_19
# quality check on acc_df for column name: _min_19
# quality check on acc_df for column name: _min_centered_19
# quality check on acc_df for column name: _var_19
# quality check on acc_df for column name: _var_centered_19
# quality check on acc_df for column name: _nat_19
# quality check on acc_df for column name: _nat_centered_19
# quality check on acc_df for column name: _anyact_19
# quality check on acc_df for column name: _anyact_centered_19
# quality check on acc_df for column name: _skew_19
# quality check on acc_df for column name: _skew_centered_19
# quality check on acc_df for column name: _kurt_19
# quality check on acc_df for column name: _kurt_centered_19
# quality check on acc_df for column name: _Act
# quality check on acc_df for column name: _LocAct
#  Not given scaler start training scaler now!
# start transform dataset frame :acc_df
#   0%|                                                                              | 1/2237 [00:17<10:46:33, 17.35s/it]
# ****************************************************************************************************
# Processing subject 0002 dataset
# pre-processing dataset frame using comprehensive method
# quality check on acc_df for column name: offwrist
# quality check on acc_df for column name: marker
# quality check on acc_df for column name: whitelight
# quality check on acc_df for column name: redlight
# quality check on acc_df for column name: greenlight
# quality check on acc_df for column name: bluelight
# quality check on acc_df for column name: dayofweek
# quality check on acc_df for column name: daybymidnight
# quality check on acc_df for column name: daybynoon
# quality check on acc_df for column name: _mean_1
# quality check on acc_df for column name: _mean_centered_1
# quality check on acc_df for column name: _median_1
# quality check on acc_df for column name: _median_centered_1
# quality check on acc_df for column name: _std_1
# quality check on acc_df for column name: _std_centered_1
# quality check on acc_df for column name: _max_1
# quality check on acc_df for column name: _max_centered_1
# quality check on acc_df for column name: _min_1
# quality check on acc_df for column name: _min_centered_1
# quality check on acc_df for column name: _var_1
# quality check on acc_df for column name: _var_centered_1
# quality check on acc_df for column name: _nat_1
# quality check on acc_df for column name: _nat_centered_1
# quality check on acc_df for column name: _anyact_1
# quality check on acc_df for column name: _anyact_centered_1
# quality check on acc_df for column name: _mean_2
# quality check on acc_df for column name: _mean_centered_2
# quality check on acc_df for column name: _median_2
# quality check on acc_df for column name: _median_centered_2
# quality check on acc_df for column name: _std_2
# quality check on acc_df for column name: _std_centered_2
# quality check on acc_df for column name: _max_2
# quality check on acc_df for column name: _max_centered_2
# quality check on acc_df for column name: _min_2
# quality check on acc_df for column name: _min_centered_2
# quality check on acc_df for column name: _var_2
# quality check on acc_df for column name: _var_centered_2
# quality check on acc_df for column name: _nat_2
# quality check on acc_df for column name: _nat_centered_2
# quality check on acc_df for column name: _anyact_2
# quality check on acc_df for column name: _anyact_centered_2
# quality check on acc_df for column name: _mean_3
# quality check on acc_df for column name: _mean_centered_3
# quality check on acc_df for column name: _median_3
# quality check on acc_df for column name: _median_centered_3
# quality check on acc_df for column name: _std_3
# quality check on acc_df for column name: _std_centered_3
# quality check on acc_df for column name: _max_3
# quality check on acc_df for column name: _max_centered_3
# quality check on acc_df for column name: _min_3
# quality check on acc_df for column name: _min_centered_3
# quality check on acc_df for column name: _var_3
# quality check on acc_df for column name: _var_centered_3
# quality check on acc_df for column name: _nat_3
# quality check on acc_df for column name: _nat_centered_3
# quality check on acc_df for column name: _anyact_3
# quality check on acc_df for column name: _anyact_centered_3
# quality check on acc_df for column name: _mean_4
# quality check on acc_df for column name: _mean_centered_4
# quality check on acc_df for column name: _median_4
# quality check on acc_df for column name: _median_centered_4
# quality check on acc_df for column name: _std_4
# quality check on acc_df for column name: _std_centered_4
# quality check on acc_df for column name: _max_4
# quality check on acc_df for column name: _max_centered_4
# quality check on acc_df for column name: _min_4
# quality check on acc_df for column name: _min_centered_4
# quality check on acc_df for column name: _var_4
# quality check on acc_df for column name: _var_centered_4
# quality check on acc_df for column name: _nat_4
# quality check on acc_df for column name: _nat_centered_4
# quality check on acc_df for column name: _anyact_4
# quality check on acc_df for column name: _anyact_centered_4
# quality check on acc_df for column name: _skew_4
# quality check on acc_df for column name: _skew_centered_4
# quality check on acc_df for column name: _kurt_4
# quality check on acc_df for column name: _kurt_centered_4
# quality check on acc_df for column name: _mean_5
# quality check on acc_df for column name: _mean_centered_5
# quality check on acc_df for column name: _median_5
# quality check on acc_df for column name: _median_centered_5
# quality check on acc_df for column name: _std_5
# quality check on acc_df for column name: _std_centered_5
# quality check on acc_df for column name: _max_5
# quality check on acc_df for column name: _max_centered_5
# quality check on acc_df for column name: _min_5
# quality check on acc_df for column name: _min_centered_5
# quality check on acc_df for column name: _var_5
# quality check on acc_df for column name: _var_centered_5
# quality check on acc_df for column name: _nat_5
# quality check on acc_df for column name: _nat_centered_5
# quality check on acc_df for column name: _anyact_5
# quality check on acc_df for column name: _anyact_centered_5
# quality check on acc_df for column name: _skew_5
# quality check on acc_df for column name: _skew_centered_5
# quality check on acc_df for column name: _kurt_5
# quality check on acc_df for column name: _kurt_centered_5
# quality check on acc_df for column name: _mean_6
# quality check on acc_df for column name: _mean_centered_6
# quality check on acc_df for column name: _median_6
# quality check on acc_df for column name: _median_centered_6
# quality check on acc_df for column name: _std_6
# quality check on acc_df for column name: _std_centered_6
# quality check on acc_df for column name: _max_6
# quality check on acc_df for column name: _max_centered_6
# quality check on acc_df for column name: _min_6
# quality check on acc_df for column name: _min_centered_6
# quality check on acc_df for column name: _var_6
# quality check on acc_df for column name: _var_centered_6
# quality check on acc_df for column name: _nat_6
# quality check on acc_df for column name: _nat_centered_6
# quality check on acc_df for column name: _anyact_6
# quality check on acc_df for column name: _anyact_centered_6
# quality check on acc_df for column name: _skew_6
# quality check on acc_df for column name: _skew_centered_6
# quality check on acc_df for column name: _kurt_6
# quality check on acc_df for column name: _kurt_centered_6
# quality check on acc_df for column name: _mean_7
# quality check on acc_df for column name: _mean_centered_7
# quality check on acc_df for column name: _median_7
# quality check on acc_df for column name: _median_centered_7
# quality check on acc_df for column name: _std_7
# quality check on acc_df for column name: _std_centered_7
# quality check on acc_df for column name: _max_7
# quality check on acc_df for column name: _max_centered_7
# quality check on acc_df for column name: _min_7
# quality check on acc_df for column name: _min_centered_7
# quality check on acc_df for column name: _var_7
# quality check on acc_df for column name: _var_centered_7
# quality check on acc_df for column name: _nat_7
# quality check on acc_df for column name: _nat_centered_7
# quality check on acc_df for column name: _anyact_7
# quality check on acc_df for column name: _anyact_centered_7
# quality check on acc_df for column name: _skew_7
# quality check on acc_df for column name: _skew_centered_7
# quality check on acc_df for column name: _kurt_7
# quality check on acc_df for column name: _kurt_centered_7
# quality check on acc_df for column name: _mean_8
# quality check on acc_df for column name: _mean_centered_8
# quality check on acc_df for column name: _median_8
# quality check on acc_df for column name: _median_centered_8
# quality check on acc_df for column name: _std_8
# quality check on acc_df for column name: _std_centered_8
# quality check on acc_df for column name: _max_8
# quality check on acc_df for column name: _max_centered_8
# quality check on acc_df for column name: _min_8
# quality check on acc_df for column name: _min_centered_8
# quality check on acc_df for column name: _var_8
# quality check on acc_df for column name: _var_centered_8
# quality check on acc_df for column name: _nat_8
# quality check on acc_df for column name: _nat_centered_8
# quality check on acc_df for column name: _anyact_8
# quality check on acc_df for column name: _anyact_centered_8
# quality check on acc_df for column name: _skew_8
# quality check on acc_df for column name: _skew_centered_8
# quality check on acc_df for column name: _kurt_8
# quality check on acc_df for column name: _kurt_centered_8
# quality check on acc_df for column name: _mean_9
# quality check on acc_df for column name: _mean_centered_9
# quality check on acc_df for column name: _median_9
# quality check on acc_df for column name: _median_centered_9
# quality check on acc_df for column name: _std_9
# quality check on acc_df for column name: _std_centered_9
# quality check on acc_df for column name: _max_9
# quality check on acc_df for column name: _max_centered_9
# quality check on acc_df for column name: _min_9
# quality check on acc_df for column name: _min_centered_9
# quality check on acc_df for column name: _var_9
# quality check on acc_df for column name: _var_centered_9
# quality check on acc_df for column name: _nat_9
# quality check on acc_df for column name: _nat_centered_9
# quality check on acc_df for column name: _anyact_9
# quality check on acc_df for column name: _anyact_centered_9
# quality check on acc_df for column name: _skew_9
# quality check on acc_df for column name: _skew_centered_9
# quality check on acc_df for column name: _kurt_9
# quality check on acc_df for column name: _kurt_centered_9
# quality check on acc_df for column name: _mean_10
# quality check on acc_df for column name: _mean_centered_10
# quality check on acc_df for column name: _median_10
# quality check on acc_df for column name: _median_centered_10
# quality check on acc_df for column name: _std_10
# quality check on acc_df for column name: _std_centered_10
# quality check on acc_df for column name: _max_10
# quality check on acc_df for column name: _max_centered_10
# quality check on acc_df for column name: _min_10
# quality check on acc_df for column name: _min_centered_10
# quality check on acc_df for column name: _var_10
# quality check on acc_df for column name: _var_centered_10
# quality check on acc_df for column name: _nat_10
# quality check on acc_df for column name: _nat_centered_10
# quality check on acc_df for column name: _anyact_10
# quality check on acc_df for column name: _anyact_centered_10
# quality check on acc_df for column name: _skew_10
# quality check on acc_df for column name: _skew_centered_10
# quality check on acc_df for column name: _kurt_10
# quality check on acc_df for column name: _kurt_centered_10
# quality check on acc_df for column name: _mean_11
# quality check on acc_df for column name: _mean_centered_11
# quality check on acc_df for column name: _median_11
# quality check on acc_df for column name: _median_centered_11
# quality check on acc_df for column name: _std_11
# quality check on acc_df for column name: _std_centered_11
# quality check on acc_df for column name: _max_11
# quality check on acc_df for column name: _max_centered_11
# quality check on acc_df for column name: _min_11
# quality check on acc_df for column name: _min_centered_11
# quality check on acc_df for column name: _var_11
# quality check on acc_df for column name: _var_centered_11
# quality check on acc_df for column name: _nat_11
# quality check on acc_df for column name: _nat_centered_11
# quality check on acc_df for column name: _anyact_11
# quality check on acc_df for column name: _anyact_centered_11
# quality check on acc_df for column name: _skew_11
# quality check on acc_df for column name: _skew_centered_11
# quality check on acc_df for column name: _kurt_11
# quality check on acc_df for column name: _kurt_centered_11
# quality check on acc_df for column name: _mean_12
# quality check on acc_df for column name: _mean_centered_12
# quality check on acc_df for column name: _median_12
# quality check on acc_df for column name: _median_centered_12
# quality check on acc_df for column name: _std_12
# quality check on acc_df for column name: _std_centered_12
# quality check on acc_df for column name: _max_12
# quality check on acc_df for column name: _max_centered_12
# quality check on acc_df for column name: _min_12
# quality check on acc_df for column name: _min_centered_12
# quality check on acc_df for column name: _var_12
# quality check on acc_df for column name: _var_centered_12
# quality check on acc_df for column name: _nat_12
# quality check on acc_df for column name: _nat_centered_12
# quality check on acc_df for column name: _anyact_12
# quality check on acc_df for column name: _anyact_centered_12
# quality check on acc_df for column name: _skew_12
# quality check on acc_df for column name: _skew_centered_12
# quality check on acc_df for column name: _kurt_12
# quality check on acc_df for column name: _kurt_centered_12
# quality check on acc_df for column name: _mean_13
# quality check on acc_df for column name: _mean_centered_13
# quality check on acc_df for column name: _median_13
# quality check on acc_df for column name: _median_centered_13
# quality check on acc_df for column name: _std_13
# quality check on acc_df for column name: _std_centered_13
# quality check on acc_df for column name: _max_13
# quality check on acc_df for column name: _max_centered_13
# quality check on acc_df for column name: _min_13
# quality check on acc_df for column name: _min_centered_13
# quality check on acc_df for column name: _var_13
# quality check on acc_df for column name: _var_centered_13
# quality check on acc_df for column name: _nat_13
# quality check on acc_df for column name: _nat_centered_13
# quality check on acc_df for column name: _anyact_13
# quality check on acc_df for column name: _anyact_centered_13
# quality check on acc_df for column name: _skew_13
# quality check on acc_df for column name: _skew_centered_13
# quality check on acc_df for column name: _kurt_13
# quality check on acc_df for column name: _kurt_centered_13
# quality check on acc_df for column name: _mean_14
# quality check on acc_df for column name: _mean_centered_14
# quality check on acc_df for column name: _median_14
# quality check on acc_df for column name: _median_centered_14
# quality check on acc_df for column name: _std_14
# quality check on acc_df for column name: _std_centered_14
# quality check on acc_df for column name: _max_14
# quality check on acc_df for column name: _max_centered_14
# quality check on acc_df for column name: _min_14
# quality check on acc_df for column name: _min_centered_14
# quality check on acc_df for column name: _var_14
# quality check on acc_df for column name: _var_centered_14
# quality check on acc_df for column name: _nat_14
# quality check on acc_df for column name: _nat_centered_14
# quality check on acc_df for column name: _anyact_14
# quality check on acc_df for column name: _anyact_centered_14
# quality check on acc_df for column name: _skew_14
# quality check on acc_df for column name: _skew_centered_14
# quality check on acc_df for column name: _kurt_14
# quality check on acc_df for column name: _kurt_centered_14
# quality check on acc_df for column name: _mean_15
# quality check on acc_df for column name: _mean_centered_15
# quality check on acc_df for column name: _median_15
# quality check on acc_df for column name: _median_centered_15
# quality check on acc_df for column name: _std_15
# quality check on acc_df for column name: _std_centered_15
# quality check on acc_df for column name: _max_15
# quality check on acc_df for column name: _max_centered_15
# quality check on acc_df for column name: _min_15
# quality check on acc_df for column name: _min_centered_15
# quality check on acc_df for column name: _var_15
# quality check on acc_df for column name: _var_centered_15
# quality check on acc_df for column name: _nat_15
# quality check on acc_df for column name: _nat_centered_15
# quality check on acc_df for column name: _anyact_15
# quality check on acc_df for column name: _anyact_centered_15
# quality check on acc_df for column name: _skew_15
# quality check on acc_df for column name: _skew_centered_15
# quality check on acc_df for column name: _kurt_15
# quality check on acc_df for column name: _kurt_centered_15
# quality check on acc_df for column name: _mean_16
# quality check on acc_df for column name: _mean_centered_16
# quality check on acc_df for column name: _median_16
# quality check on acc_df for column name: _median_centered_16
# quality check on acc_df for column name: _std_16
# quality check on acc_df for column name: _std_centered_16
# quality check on acc_df for column name: _max_16
# quality check on acc_df for column name: _max_centered_16
# quality check on acc_df for column name: _min_16
# quality check on acc_df for column name: _min_centered_16
# quality check on acc_df for column name: _var_16
# quality check on acc_df for column name: _var_centered_16
# quality check on acc_df for column name: _nat_16
# quality check on acc_df for column name: _nat_centered_16
# quality check on acc_df for column name: _anyact_16
# quality check on acc_df for column name: _anyact_centered_16
# quality check on acc_df for column name: _skew_16
# quality check on acc_df for column name: _skew_centered_16
# quality check on acc_df for column name: _kurt_16
# quality check on acc_df for column name: _kurt_centered_16
# quality check on acc_df for column name: _mean_17
# quality check on acc_df for column name: _mean_centered_17
# quality check on acc_df for column name: _median_17
# quality check on acc_df for column name: _median_centered_17
# quality check on acc_df for column name: _std_17
# quality check on acc_df for column name: _std_centered_17
# quality check on acc_df for column name: _max_17
# quality check on acc_df for column name: _max_centered_17
# quality check on acc_df for column name: _min_17
# quality check on acc_df for column name: _min_centered_17
# quality check on acc_df for column name: _var_17
# quality check on acc_df for column name: _var_centered_17
# quality check on acc_df for column name: _nat_17
# quality check on acc_df for column name: _nat_centered_17
# quality check on acc_df for column name: _anyact_17
# quality check on acc_df for column name: _anyact_centered_17
# quality check on acc_df for column name: _skew_17
# quality check on acc_df for column name: _skew_centered_17
# quality check on acc_df for column name: _kurt_17
# quality check on acc_df for column name: _kurt_centered_17
# quality check on acc_df for column name: _mean_18
# quality check on acc_df for column name: _mean_centered_18
# quality check on acc_df for column name: _median_18
# quality check on acc_df for column name: _median_centered_18
# quality check on acc_df for column name: _std_18
# quality check on acc_df for column name: _std_centered_18
# quality check on acc_df for column name: _max_18
# quality check on acc_df for column name: _max_centered_18
# quality check on acc_df for column name: _min_18
# quality check on acc_df for column name: _min_centered_18
# quality check on acc_df for column name: _var_18
# quality check on acc_df for column name: _var_centered_18
# quality check on acc_df for column name: _nat_18
# quality check on acc_df for column name: _nat_centered_18
# quality check on acc_df for column name: _anyact_18
# quality check on acc_df for column name: _anyact_centered_18
# quality check on acc_df for column name: _skew_18
# quality check on acc_df for column name: _skew_centered_18
# quality check on acc_df for column name: _kurt_18
# quality check on acc_df for column name: _kurt_centered_18
# quality check on acc_df for column name: _mean_19
# quality check on acc_df for column name: _mean_centered_19
# quality check on acc_df for column name: _median_19
# quality check on acc_df for column name: _median_centered_19
# quality check on acc_df for column name: _std_19
# quality check on acc_df for column name: _std_centered_19
# quality check on acc_df for column name: _max_19
# quality check on acc_df for column name: _max_centered_19
# quality check on acc_df for column name: _min_19
# quality check on acc_df for column name: _min_centered_19
# quality check on acc_df for column name: _var_19
# quality check on acc_df for column name: _var_centered_19
# quality check on acc_df for column name: _nat_19
# quality check on acc_df for column name: _nat_centered_19
# quality check on acc_df for column name: _anyact_19
# quality check on acc_df for column name: _anyact_centered_19
# quality check on acc_df for column name: _skew_19
# quality check on acc_df for column name: _skew_centered_19
# quality check on acc_df for column name: _kurt_19
# quality check on acc_df for column name: _kurt_centered_19
# quality check on acc_df for column name: _Act
# quality check on acc_df for column name: _LocAct
#  Not given scaler start training scaler now!
# start transform dataset frame :acc_df
#   0%|                                                                               | 2/2237 [00:28<9:39:23, 15.55s/it]
# ****************************************************************************************************
# Processing subject 0006 dataset
# pre-processing dataset frame using comprehensive method
# quality check on acc_df for column name: offwrist
# quality check on acc_df for column name: marker
# quality check on acc_df for column name: whitelight
# quality check on acc_df for column name: redlight
# quality check on acc_df for column name: greenlight
# quality check on acc_df for column name: bluelight
# quality check on acc_df for column name: dayofweek
# quality check on acc_df for column name: daybymidnight
# quality check on acc_df for column name: daybynoon
# quality check on acc_df for column name: _mean_1
# quality check on acc_df for column name: _mean_centered_1
# quality check on acc_df for column name: _median_1
# quality check on acc_df for column name: _median_centered_1
# quality check on acc_df for column name: _std_1
# quality check on acc_df for column name: _std_centered_1
# quality check on acc_df for column name: _max_1
# quality check on acc_df for column name: _max_centered_1
# quality check on acc_df for column name: _min_1
# quality check on acc_df for column name: _min_centered_1
# quality check on acc_df for column name: _var_1
# quality check on acc_df for column name: _var_centered_1
# quality check on acc_df for column name: _nat_1
# quality check on acc_df for column name: _nat_centered_1
# quality check on acc_df for column name: _anyact_1
# quality check on acc_df for column name: _anyact_centered_1
# quality check on acc_df for column name: _mean_2
# quality check on acc_df for column name: _mean_centered_2
# quality check on acc_df for column name: _median_2
# quality check on acc_df for column name: _median_centered_2
# quality check on acc_df for column name: _std_2
# quality check on acc_df for column name: _std_centered_2
# quality check on acc_df for column name: _max_2
# quality check on acc_df for column name: _max_centered_2
# quality check on acc_df for column name: _min_2
# quality check on acc_df for column name: _min_centered_2
# quality check on acc_df for column name: _var_2
# quality check on acc_df for column name: _var_centered_2
# quality check on acc_df for column name: _nat_2
# quality check on acc_df for column name: _nat_centered_2
# quality check on acc_df for column name: _anyact_2
# quality check on acc_df for column name: _anyact_centered_2
# quality check on acc_df for column name: _mean_3
# quality check on acc_df for column name: _mean_centered_3
# quality check on acc_df for column name: _median_3
# quality check on acc_df for column name: _median_centered_3
# quality check on acc_df for column name: _std_3
# quality check on acc_df for column name: _std_centered_3
# quality check on acc_df for column name: _max_3
# quality check on acc_df for column name: _max_centered_3
# quality check on acc_df for column name: _min_3
# quality check on acc_df for column name: _min_centered_3
# quality check on acc_df for column name: _var_3
# quality check on acc_df for column name: _var_centered_3
# quality check on acc_df for column name: _nat_3
# quality check on acc_df for column name: _nat_centered_3
# quality check on acc_df for column name: _anyact_3
# quality check on acc_df for column name: _anyact_centered_3
# quality check on acc_df for column name: _mean_4
# quality check on acc_df for column name: _mean_centered_4
# quality check on acc_df for column name: _median_4
# quality check on acc_df for column name: _median_centered_4
# quality check on acc_df for column name: _std_4
# quality check on acc_df for column name: _std_centered_4
# quality check on acc_df for column name: _max_4
# quality check on acc_df for column name: _max_centered_4
# quality check on acc_df for column name: _min_4
# quality check on acc_df for column name: _min_centered_4
# quality check on acc_df for column name: _var_4
# quality check on acc_df for column name: _var_centered_4
# quality check on acc_df for column name: _nat_4
# quality check on acc_df for column name: _nat_centered_4
# quality check on acc_df for column name: _anyact_4
# quality check on acc_df for column name: _anyact_centered_4
# quality check on acc_df for column name: _skew_4
# quality check on acc_df for column name: _skew_centered_4
# quality check on acc_df for column name: _kurt_4
# quality check on acc_df for column name: _kurt_centered_4
# quality check on acc_df for column name: _mean_5
# quality check on acc_df for column name: _mean_centered_5
# quality check on acc_df for column name: _median_5
# quality check on acc_df for column name: _median_centered_5
# quality check on acc_df for column name: _std_5
# quality check on acc_df for column name: _std_centered_5
# quality check on acc_df for column name: _max_5
# quality check on acc_df for column name: _max_centered_5
# quality check on acc_df for column name: _min_5
# quality check on acc_df for column name: _min_centered_5
# quality check on acc_df for column name: _var_5
# quality check on acc_df for column name: _var_centered_5
# quality check on acc_df for column name: _nat_5
# quality check on acc_df for column name: _nat_centered_5
# quality check on acc_df for column name: _anyact_5
# quality check on acc_df for column name: _anyact_centered_5
# quality check on acc_df for column name: _skew_5
# quality check on acc_df for column name: _skew_centered_5
# quality check on acc_df for column name: _kurt_5
# quality check on acc_df for column name: _kurt_centered_5
# quality check on acc_df for column name: _mean_6
# quality check on acc_df for column name: _mean_centered_6
# quality check on acc_df for column name: _median_6
# quality check on acc_df for column name: _median_centered_6
# quality check on acc_df for column name: _std_6
# quality check on acc_df for column name: _std_centered_6
# quality check on acc_df for column name: _max_6
# quality check on acc_df for column name: _max_centered_6
# quality check on acc_df for column name: _min_6
# quality check on acc_df for column name: _min_centered_6
# quality check on acc_df for column name: _var_6
# quality check on acc_df for column name: _var_centered_6
# quality check on acc_df for column name: _nat_6
# quality check on acc_df for column name: _nat_centered_6
# quality check on acc_df for column name: _anyact_6
# quality check on acc_df for column name: _anyact_centered_6
# quality check on acc_df for column name: _skew_6
# ...
# quality check on acc_df for column name: _median_7
# quality check on acc_df for column name: _median_centered_7
# quality check on acc_df for column name: _std_7
# quality check on acc_df for column name: _std_centered_7
# quality check on acc_df for column name: _max_7
# quality check on acc_df for column name: _max_centered_7
# quality check on acc_df for column name: _min_7
# quality check on acc_df for column name: _min_centered_7
# quality check on acc_df for column name: _var_7
# quality check on acc_df for column name: _var_centered_7
# quality check on acc_df for column name: _nat_7
# quality check on acc_df for column name: _nat_centered_7
# quality check on acc_df for column name: _anyact_7
# quality check on acc_df for column name: _anyact_centered_7
# quality check on acc_df for column name: _skew_7
# quality check on acc_df for column name: _skew_centered_7
# quality check on acc_df for column name: _kurt_7
# quality check on acc_df for column name: _kurt_centered_7
# quality check on acc_df for column name: _mean_8
# quality check on acc_df for column name: _mean_centered_8
# quality check on acc_df for column name: _median_8
# quality check on acc_df for column name: _median_centered_8
# quality check on acc_df for column name: _std_8
# quality check on acc_df for column name: _std_centered_8
# quality check on acc_df for column name: _max_8
# quality check on acc_df for column name: _max_centered_8
# quality check on acc_df for column name: _min_8
# quality check on acc_df for column name: _min_centered_8
# quality check on acc_df for column name: _var_8
# quality check on acc_df for column name: _var_centered_8
# quality check on acc_df for column name: _nat_8
# quality check on acc_df for column name: _nat_centered_8
# quality check on acc_df for column name: _anyact_8
# quality check on acc_df for column name: _anyact_centered_8
# quality check on acc_df for column name: _skew_8
# quality check on acc_df for column name: _skew_centered_8
# quality check on acc_df for column name: _kurt_8
# quality check on acc_df for column name: _kurt_centered_8
# quality check on acc_df for column name: _mean_9
# quality check on acc_df for column name: _mean_centered_9
# quality check on acc_df for column name: _median_9
# quality check on acc_df for column name: _median_centered_9
# quality check on acc_df for column name: _std_9
# quality check on acc_df for column name: _std_centered_9
# quality check on acc_df for column name: _max_9
# quality check on acc_df for column name: _max_centered_9
# quality check on acc_df for column name: _min_9
# quality check on acc_df for column name: _min_centered_9
# quality check on acc_df for column name: _var_9
# quality check on acc_df for column name: _var_centered_9
# quality check on acc_df for column name: _nat_9
# quality check on acc_df for column name: _nat_centered_9
# quality check on acc_df for column name: _anyact_9
# quality check on acc_df for column name: _anyact_centered_9
# quality check on acc_df for column name: _skew_9
# quality check on acc_df for column name: _skew_centered_9
# quality check on acc_df for column name: _kurt_9
# quality check on acc_df for column name: _kurt_centered_9
# quality check on acc_df for column name: _mean_10
# quality check on acc_df for column name: _mean_centered_10
# quality check on acc_df for column name: _median_10
# quality check on acc_df for column name: _median_centered_10
# quality check on acc_df for column name: _std_10
# quality check on acc_df for column name: _std_centered_10
# quality check on acc_df for column name: _max_10
# quality check on acc_df for column name: _max_centered_10
# quality check on acc_df for column name: _min_10
# quality check on acc_df for column name: _min_centered_10
# quality check on acc_df for column name: _var_10
# quality check on acc_df for column name: _var_centered_10
# quality check on acc_df for column name: _nat_10
# quality check on acc_df for column name: _nat_centered_10
# quality check on acc_df for column name: _anyact_10
# quality check on acc_df for column name: _anyact_centered_10
# quality check on acc_df for column name: _skew_10
# quality check on acc_df for column name: _skew_centered_10
# quality check on acc_df for column name: _kurt_10
# quality check on acc_df for column name: _kurt_centered_10
# quality check on acc_df for column name: _mean_11
# quality check on acc_df for column name: _mean_centered_11
# quality check on acc_df for column name: _median_11
# quality check on acc_df for column name: _median_centered_11
# quality check on acc_df for column name: _std_11
# quality check on acc_df for column name: _std_centered_11
# quality check on acc_df for column name: _max_11
# quality check on acc_df for column name: _max_centered_11
# quality check on acc_df for column name: _min_11
# quality check on acc_df for column name: _min_centered_11
# quality check on acc_df for column name: _var_11
# quality check on acc_df for column name: _var_centered_11
# quality check on acc_df for column name: _nat_11
# quality check on acc_df for column name: _nat_centered_11
# quality check on acc_df for column name: _anyact_11
# quality check on acc_df for column name: _anyact_centered_11
# quality check on acc_df for column name: _skew_11
# quality check on acc_df for column name: _skew_centered_11
# quality check on acc_df for column name: _kurt_11
# quality check on acc_df for column name: _kurt_centered_11
# quality check on acc_df for column name: _mean_12
# quality check on acc_df for column name: _mean_centered_12
# quality check on acc_df for column name: _median_12
# quality check on acc_df for column name: _median_centered_12
# quality check on acc_df for column name: _std_12
# quality check on acc_df for column name: _std_centered_12
# quality check on acc_df for column name: _max_12
# quality check on acc_df for column name: _max_centered_12
# quality check on acc_df for column name: _min_12
# quality check on acc_df for column name: _min_centered_12
# quality check on acc_df for column name: _var_12
# quality check on acc_df for column name: _var_centered_12
# quality check on acc_df for column name: _nat_12
# quality check on acc_df for column name: _nat_centered_12
# quality check on acc_df for column name: _anyact_12
# quality check on acc_df for column name: _anyact_centered_12
# quality check on acc_df for column name: _skew_12
# quality check on acc_df for column name: _skew_centered_12
# quality check on acc_df for column name: _kurt_12
# quality check on acc_df for column name: _kurt_centered_12
# quality check on acc_df for column name: _mean_13
# quality check on acc_df for column name: _mean_centered_13
# quality check on acc_df for column name: _median_13
# quality check on acc_df for column name: _median_centered_13
# quality check on acc_df for column name: _std_13
# quality check on acc_df for column name: _std_centered_13
# quality check on acc_df for column name: _max_13
# quality check on acc_df for column name: _max_centered_13
# quality check on acc_df for column name: _min_13
# quality check on acc_df for column name: _min_centered_13
# quality check on acc_df for column name: _var_13
# quality check on acc_df for column name: _var_centered_13
# quality check on acc_df for column name: _nat_13
# quality check on acc_df for column name: _nat_centered_13
# quality check on acc_df for column name: _anyact_13
# quality check on acc_df for column name: _anyact_centered_13
# quality check on acc_df for column name: _skew_13
# quality check on acc_df for column name: _skew_centered_13
# quality check on acc_df for column name: _kurt_13
# quality check on acc_df for column name: _kurt_centered_13
# quality check on acc_df for column name: _mean_14
# quality check on acc_df for column name: _mean_centered_14
# quality check on acc_df for column name: _median_14
# quality check on acc_df for column name: _median_centered_14
# quality check on acc_df for column name: _std_14
# quality check on acc_df for column name: _std_centered_14
# quality check on acc_df for column name: _max_14
# quality check on acc_df for column name: _max_centered_14
# quality check on acc_df for column name: _min_14
# quality check on acc_df for column name: _min_centered_14
# quality check on acc_df for column name: _var_14
# quality check on acc_df for column name: _var_centered_14
# quality check on acc_df for column name: _nat_14
# quality check on acc_df for column name: _nat_centered_14
# quality check on acc_df for column name: _anyact_14
# quality check on acc_df for column name: _anyact_centered_14
# quality check on acc_df for column name: _skew_14
# quality check on acc_df for column name: _skew_centered_14
# quality check on acc_df for column name: _kurt_14
# quality check on acc_df for column name: _kurt_centered_14
# quality check on acc_df for column name: _mean_15
# quality check on acc_df for column name: _mean_centered_15
# quality check on acc_df for column name: _median_15
# quality check on acc_df for column name: _median_centered_15
# quality check on acc_df for column name: _std_15
# quality check on acc_df for column name: _std_centered_15
# quality check on acc_df for column name: _max_15
# quality check on acc_df for column name: _max_centered_15
# quality check on acc_df for column name: _min_15
# quality check on acc_df for column name: _min_centered_15
# quality check on acc_df for column name: _var_15
# quality check on acc_df for column name: _var_centered_15
# quality check on acc_df for column name: _nat_15
# quality check on acc_df for column name: _nat_centered_15
# quality check on acc_df for column name: _anyact_15
# quality check on acc_df for column name: _anyact_centered_15
# quality check on acc_df for column name: _skew_15
# quality check on acc_df for column name: _skew_centered_15
# quality check on acc_df for column name: _kurt_15
# quality check on acc_df for column name: _kurt_centered_15
# quality check on acc_df for column name: _mean_16
# quality check on acc_df for column name: _mean_centered_16
# quality check on acc_df for column name: _median_16
# quality check on acc_df for column name: _median_centered_16
# quality check on acc_df for column name: _std_16
# quality check on acc_df for column name: _std_centered_16
# quality check on acc_df for column name: _max_16
# quality check on acc_df for column name: _max_centered_16
# quality check on acc_df for column name: _min_16
# quality check on acc_df for column name: _min_centered_16
# quality check on acc_df for column name: _var_16
# quality check on acc_df for column name: _var_centered_16
# quality check on acc_df for column name: _nat_16
# quality check on acc_df for column name: _nat_centered_16
# quality check on acc_df for column name: _anyact_16
# quality check on acc_df for column name: _anyact_centered_16
# quality check on acc_df for column name: _skew_16
# quality check on acc_df for column name: _skew_centered_16
# quality check on acc_df for column name: _kurt_16
# quality check on acc_df for column name: _kurt_centered_16
# quality check on acc_df for column name: _mean_17
# quality check on acc_df for column name: _mean_centered_17
# quality check on acc_df for column name: _median_17
# quality check on acc_df for column name: _median_centered_17
# quality check on acc_df for column name: _std_17
# quality check on acc_df for column name: _std_centered_17
# quality check on acc_df for column name: _max_17
# quality check on acc_df for column name: _max_centered_17
# quality check on acc_df for column name: _min_17
# quality check on acc_df for column name: _min_centered_17
# quality check on acc_df for column name: _var_17
# quality check on acc_df for column name: _var_centered_17
# quality check on acc_df for column name: _nat_17
# quality check on acc_df for column name: _nat_centered_17
# quality check on acc_df for column name: _anyact_17
# quality check on acc_df for column name: _anyact_centered_17
# quality check on acc_df for column name: _skew_17
# quality check on acc_df for column name: _skew_centered_17
# quality check on acc_df for column name: _kurt_17
# quality check on acc_df for column name: _kurt_centered_17
# quality check on acc_df for column name: _mean_18
# quality check on acc_df for column name: _mean_centered_18
# quality check on acc_df for column name: _median_18
# quality check on acc_df for column name: _median_centered_18
# quality check on acc_df for column name: _std_18
# quality check on acc_df for column name: _std_centered_18
# quality check on acc_df for column name: _max_18
# quality check on acc_df for column name: _max_centered_18
# quality check on acc_df for column name: _min_18
# quality check on acc_df for column name: _min_centered_18
# quality check on acc_df for column name: _var_18
# quality check on acc_df for column name: _var_centered_18
# quality check on acc_df for column name: _nat_18
# quality check on acc_df for column name: _nat_centered_18
# quality check on acc_df for column name: _anyact_18
# quality check on acc_df for column name: _anyact_centered_18
# quality check on acc_df for column name: _skew_18
# quality check on acc_df for column name: _skew_centered_18
# quality check on acc_df for column name: _kurt_18
# quality check on acc_df for column name: _kurt_centered_18
# quality check on acc_df for column name: _mean_19
# quality check on acc_df for column name: _mean_centered_19
# quality check on acc_df for column name: _median_19
# quality check on acc_df for column name: _median_centered_19
# quality check on acc_df for column name: _std_19
# quality check on acc_df for column name: _std_centered_19
# quality check on acc_df for column name: _max_19
# quality check on acc_df for column name: _max_centered_19
# quality check on acc_df for column name: _min_19
# quality check on acc_df for column name: _min_centered_19
# quality check on acc_df for column name: _var_19
# quality check on acc_df for column name: _var_centered_19
# quality check on acc_df for column name: _nat_19
# quality check on acc_df for column name: _nat_centered_19
# quality check on acc_df for column name: _anyact_19
# quality check on acc_df for column name: _anyact_centered_19
# quality check on acc_df for column name: _skew_19
# quality check on acc_df for column name: _skew_centered_19
# quality check on acc_df for column name: _kurt_19
# quality check on acc_df for column name: _kurt_centered_19
# quality check on acc_df for column name: _Act
# quality check on acc_df for column name: _LocAct
#  Not given scaler start training scaler now!
# start transform dataset frame :acc_df
#   0%|▏                                                                              | 4/2237 [01:01<9:31:09, 15.35s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-86f6eb723c61> in <module>
#      35             if standarize_feature:
#      36                 standardize_df_given_feature(acc_df, std_feature, df_name='acc_df', simple_method=False)
# ---> 37             acc_df.to_csv(os.path.join(acc_feature_output_path, (mesa_id + '_act_features.csv')), index=False)
#
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3202             decimal=decimal,
#    3203         )
# -> 3204         formatter.save()
#    3205
#    3206         if path_or_buf is None:
#
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     202             )
#     203
# --> 204             self._save()
#     205
#     206         finally:
#
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\pandas\io\formats\csvs.py in _save(self)
#     323                 break
#     324
# --> 325             self._save_chunk(start_i, end_i)
#     326
#     327     def _save_chunk(self, start_i: int, end_i: int) -> None:
#
# c:\users\admin\anaconda3\envs\tf2\lib\site-packages\pandas\io\formats\csvs.py in _save_chunk(self, start_i, end_i)
#     354         )
#     355
# --> 356         libwriters.write_csv_rows(self.data, ix, self.nlevels, self.cols, self.writer)
#
# pandas\_libs\writers.pyx in pandas._libs.writers.write_csv_rows()
#
# KeyboardInterrupt:
